# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path=r"C:\Users\DELL\Downloads\creditcard.csv\creditcard.csv"
data=pd.read_csv(file_path)

# %%
data.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.duplicated().sum()
# Out:
# 1081

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#recovery of fraud data

# %%
df_fraud=data[data['Class'] == 1]
plt.figure(figsize=(10,6))
plt.scatter(df_fraud['Time'],df_fraud['Amount'])
plt.title('scatter plot amount fraud with respect to Time')
plt.xlabel('Time')
plt.ylabel('Amount')
plt.show()

# %%
number_fraud = len(data[data.Class == 1])
number_no_fraud = len(data[data.Class == 0])
print('Number of frauds:',number_fraud)
print('Number of no frauds: ',number_no_fraud)
# Out:
# Number of frauds: 492
# Number of no frauds:  284315

# %%
fraud = data[data['Class'] == 1]
no_fraud = data[data['Class'] == 0]

# %%
pd.concat([no_fraud.Amount.describe() , no_fraud.Time.describe()] , axis=1)
# Out:
#               Amount           Time
# count  284315.000000  284315.000000
# mean       88.291022   94838.202258
# std       250.105092   47484.015786
# min         0.000000       0.000000
# 25%         5.650000   54230.000000
# 50%        22.000000   84711.000000
# 75%        77.050000  139333.000000
# max     25691.160000  172792.000000

# %%
pd.concat([fraud.Amount.describe() , fraud.Time.describe()] , axis=1)
# Out:
#             Amount           Time
# count   492.000000     492.000000
# mean    122.211321   80746.806911
# std     256.683288   47835.365138
# min       0.000000     406.000000
# 25%       1.000000   41241.500000
# 50%       9.250000   75568.500000
# 75%     105.890000  128483.000000
# max    2125.870000  170348.000000

# %%
fraud.shape
# Out:
# (492, 31)

# %%
no_fraud.shape
# Out:
# (284315, 31)

# %%
#sample selection

# %%
from sklearn.preprocessing import StandardScaler,RobustScaler

# %%
std_scaler = StandardScaler()
rob_scaler = RobustScaler()

# %%
data['amount_scale'] = rob_scaler.fit_transform(data['Amount'].values.reshape(-1,1))

# %%
data['time_scale'] = rob_scaler.fit_transform(data['Time'].values.reshape(-1,1))

# %%
data.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V23       V24       V25       V26       V27  \
# 0  0.098698  0.363787  ... -0.110474  0.066928  0.128539 -0.189115  0.133558
# 1  0.085102 -0.255425  ...  0.101288 -0.339846  0.167170  0.125895 -0.008983
# 2  0.247676 -1.514654  ...  0.909412 -0.689281 -0.327642 -0.139097 -0.055353
# 3  0.377436 -1.387024  ... -0.190321 -1.175575  0.647376 -0.221929  0.062723
# 4 -0.270533  0.817739  ... -0.137458  0.141267 -0.206010  0.502292  0.219422
#
# ...

# %%
data.drop(['Time','Amount'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   V1            284807 non-null  float64
#  1   V2            284807 non-null  float64
#  2   V3            284807 non-null  float64
#  3   V4            284807 non-null  float64
#  4   V5            284807 non-null  float64
#  5   V6            284807 non-null  float64
#  6   V7            284807 non-null  float64
#  7   V8            284807 non-null  float64
#  8   V9            284807 non-null  float64
#  9   V10           284807 non-null  float64
#  10  V11           284807 non-null  float64
#  11  V12           284807 non-null  float64
#  12  V13           284807 non-null  float64
#  13  V14           284807 non-null  float64
#  14  V15           284807 non-null  float64
#  15  V16           284807 non-null  float64
#  16  V17           284807 non-null  float64
# ...

# %%
amount_scale = data['amount_scale']
time_scale = data['time_scale']

# %%
data.drop(['amount_scale', 'time_scale'], axis=1, inplace=True)
data.insert(0, 'amount_scale', amount_scale)
data.insert(1, 'time_scale', time_scale)

# %%
data.head(5)
# Out:
#    amount_scale  time_scale        V1        V2        V3        V4        V5  \
# 0      1.783274   -0.994983 -1.359807 -0.072781  2.536347  1.378155 -0.338321
# 1     -0.269825   -0.994983  1.191857  0.266151  0.166480  0.448154  0.060018
# 2      4.983721   -0.994972 -1.358354 -1.340163  1.773209  0.379780 -0.503198
# 3      1.418291   -0.994972 -0.966272 -0.185226  1.792993 -0.863291 -0.010309
# 4      0.670579   -0.994960 -1.158233  0.877737  1.548718  0.403034 -0.407193
#
#          V6        V7        V8  ...       V20       V21       V22       V23  \
# 0  0.462388  0.239599  0.098698  ...  0.251412 -0.018307  0.277838 -0.110474
# 1 -0.082361 -0.078803  0.085102  ... -0.069083 -0.225775 -0.638672  0.101288
# 2  1.800499  0.791461  0.247676  ...  0.524980  0.247998  0.771679  0.909412
# 3  1.247203  0.237609  0.377436  ... -0.208038 -0.108300  0.005274 -0.190321
# 4  0.095921  0.592941 -0.270533  ...  0.408542 -0.009431  0.798278 -0.137458
#
# ...

# %%
data = data.sample(frac=0.5)

# %%
data.head(5)
# Out:
#         amount_scale  time_scale        V1        V2        V3        V4  \
# 168660     -0.294977    0.406889  2.025885 -0.041079 -1.247961  0.273743
# 255239     -0.293579    0.851009 -0.435945  0.930726  0.039231 -0.815325
# 85590       0.391253   -0.280208 -0.213679  0.409990  0.061892 -1.163371
# 249064      0.391113    0.816903  1.892384 -0.436772 -0.307607  0.493461
# 146092     -0.120170    0.032214  2.016287 -0.002010 -1.640305  0.988195
#
#               V5        V6        V7        V8  ...       V20       V21  \
# 168660 -0.021412 -1.098075  0.159361 -0.267669  ... -0.236668  0.302940
# 255239  0.686829 -0.673564  0.885155 -0.095494  ...  0.066183 -0.259654
# 85590  -0.291369 -0.068158  0.103698  0.409548  ... -0.033725  0.029465
# 249064 -0.739300 -0.657913 -0.410147 -0.074173  ... -0.149402 -0.148696
# 146092  0.655788 -0.033044  0.154154  0.017342  ... -0.302891 -0.155888
#
#              V22       V23       V24       V25       V26       V27       V28  \
# ...

# %%
fraud = data.loc[data['Class'] == 1]
no_fraud = data.loc[data['Class'] == 0][:492]

# %%
normal_distributed_data = pd.concat([fraud, no_fraud])

# %%
sample_data = normal_distributed_data.sample(frac=1, random_state=42)
sample_data.head()
# Out:
#         amount_scale  time_scale        V1        V2        V3        V4  \
# 151971     -0.181793    0.139851 -0.403388  0.778043  1.601850 -0.465478
# 102782     -0.033676   -0.191908  1.232604 -0.548931  1.087873  0.894082
# 47089       0.485293   -0.488904  1.124220 -0.304699  0.991569  0.784876
# 251881     -0.263537    0.832364  1.868226  1.363077 -1.994934  4.173516
# 188846      1.379585    0.510650 -2.434932 -1.335462  0.694212 -0.793838
#
#               V5        V6        V7        V8  ...       V20       V21  \
# 151971  0.584135  0.645319  0.231014  0.181667  ...  0.008775 -0.230213
# 102782 -1.433055 -0.356797 -0.717492  0.003167  ... -0.576274 -0.448671
# 47089  -0.874231 -0.001747 -0.551449  0.074618  ...  0.030929 -0.092140
# 251881  1.239751 -0.746186  0.572731 -0.131235  ... -0.172216 -0.301001
# 188846  1.551129 -0.112982  1.165655 -0.138706  ... -0.470926 -0.084311
#
#              V22       V23       V24       V25       V26       V27       V28  \
# ...

# %%
X = sample_data.drop('Class' , axis = 1)
y = sample_data['Class']

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn import svm
clf = svm.SVC()

# %%
clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_train_pred = clf.predict(X_train)

# %%
print(accuracy_score(y_train, y_train_pred))
# Out:
# 0.9533980582524272

# %%
y_test_pred=clf.predict(X_test)

# %%
print(accuracy_score(y_test, y_test_pred))
# Out:
# 0.9504504504504504

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
train_precision = precision_score(y_train, y_train_pred)
test_precision = precision_score(y_test, y_test_pred)
print("Training Precision:", train_precision)
print("Test Precision:", test_precision)
# Out:
# Training Precision: 0.9933333333333333
# Test Precision: 1.0

# %%
train_f1 = f1_score(y_train, y_train_pred)
test_f1 = f1_score(y_test, y_test_pred)
print("Training F1 Score:", train_f1)
print("Test F1 Score:", test_f1)
# Out:
# Training F1 Score: 0.9254658385093167
# Test F1 Score: 0.9185185185185185

# %%
train_recall = recall_score(y_train, y_train_pred)
test_recall = recall_score(y_test, y_test_pred)
print("Training Recall:", train_recall)
print("Test Recall:", test_recall)
# Out:
# Training Recall: 0.8662790697674418
# Test Recall: 0.8493150684931506

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       149
#            1       1.00      0.85      0.92        73
#
#     accuracy                           0.95       222
#    macro avg       0.97      0.92      0.94       222
# weighted avg       0.95      0.95      0.95       222

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_test_pred)
sns.heatmap(cm, annot=True, fmt="d", cbar=False)
plt.title('SVC Confusion Matrix')
plt.savefig('svc_con_mat')
plt.show()
